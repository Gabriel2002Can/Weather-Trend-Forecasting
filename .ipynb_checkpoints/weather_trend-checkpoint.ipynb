# %% [markdown]
# # Weather Trend Forecasting Assignment

# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime

from sklearn.ensemble import IsolationForest

# %% [markdown]
# ## Importing Data

# %%
df = pd.read_csv("GlobalWeatherRepository.csv")

df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 140918    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 140919      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 140920        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 140921       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 140922     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 0               1715849100  2024-05-16 13:15                 26.6
# 1               1715849100  2024-05-16 10:45                 19.0
# 2               1715849100  2024-05-16 09:45                 23.0
# 3               1715849100  2024-05-16 10:45                  6.3
# 4               1715849100  2024-05-16 09:45                 26.0
# ...                    ...               ...                  ...
# 140918          1778567400  2026-05-12 02:30                 18.3
# 140919          1778567400  2026-05-12 13:30                 32.3
# 140920          1778567400  2026-05-12 09:30                 20.8
# 140921          1778567400  2026-05-12 08:30                 21.2
# 140922          1778567400  2026-05-12 08:30                 20.6
#
#         temperature_fahrenheit      condition_text  ...  air_quality_PM2.5  \
# 0                         79.8       Partly Cloudy  ...               8.40
# 1                         66.2       Partly cloudy  ...               1.10
# 2                         73.4               Sunny  ...              10.40
# 3                         43.3       Light drizzle  ...               0.70
# 4                         78.8       Partly cloudy  ...             183.40
# ...                        ...                 ...  ...                ...
# 140918                    64.9  Patchy rain nearby  ...               8.95
# 140919                    90.1       Partly cloudy  ...              43.55
# 140920                    69.4               Sunny  ...              12.15
# 140921                    70.1               Sunny  ...               7.45
# 140922                    69.0               Sunny  ...              14.55
#
#         air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 0                  26.60                         1                          1
# 1                   2.00                         1                          1
# 2                  18.40                         1                          1
# 3                   0.90                         1                          1
# 4                 262.30                         5                         10
# ...                  ...                       ...                        ...
# 140918             11.75                         1                          1
# 140919             46.05                         3                          5
# 140920             41.85                         1                          2
# 140921              7.65                         1                          1
# 140922             15.15                         1                          2
#
#          sunrise    sunset  moonrise   moonset       moon_phase  \
# 0       04:50 AM  06:50 PM  12:12 PM  01:11 AM   Waxing Gibbous
# 1       05:21 AM  07:54 PM  12:58 PM  02:14 AM   Waxing Gibbous
# 2       05:40 AM  07:50 PM  01:15 PM  02:14 AM   Waxing Gibbous
# 3       06:31 AM  09:11 PM  02:12 PM  03:31 AM   Waxing Gibbous
# 4       06:12 AM  05:55 PM  01:17 PM  12:38 AM   Waxing Gibbous
# ...          ...       ...       ...       ...              ...
# 140918  06:06 AM  06:42 PM  02:31 AM  02:51 PM  Waning Crescent
# 140919  05:21 AM  06:26 PM  01:46 AM  01:54 PM  Waning Crescent
# 140920  05:36 AM  06:24 PM  01:57 AM  02:11 PM  Waning Crescent
# 140921  06:20 AM  05:46 PM  01:52 AM  02:19 PM  Waning Crescent
# 140922  06:12 AM  05:32 PM  01:40 AM  02:08 PM  Waning Crescent
#
#         moon_illumination
# 0                      55
# 1                      55
# 2                      55
# 3                      55
# 4                      55
# ...                   ...
# 140918                 27
# 140919                 32
# 140920                 30
# 140921                 30
# 140922                 30
#
# [140923 rows x 41 columns]

# %% [markdown]
# ## Data Analysis

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %% [markdown]
# Remove "duplicated" features: **temperature_fahrenheit, feels_like_fahrenheit, visibility_miles, gust_mph, precip_in, pressure_in, wind_mph, last_updated_epoch**

# %%
df = df.drop(columns=["temperature_fahrenheit", "feels_like_fahrenheit", "visibility_miles", "gust_mph", "precip_in", "pressure_in", "wind_mph", "last_updated_epoch"])

df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated', 'temperature_celsius', 'condition_text', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'precip_mm', 'humidity',
#        'cloud', 'feels_like_celsius', 'visibility_km', 'uv_index', 'gust_kph',
#        'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
#        'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
#        'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index',
#        'air_quality_gb-defra-index', 'sunrise', 'sunset', 'moonrise',
#        'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df.describe()
# Out:
#             latitude      longitude  temperature_celsius       wind_kph  \
# count  140923.000000  140923.000000        140923.000000  140923.000000
# mean       19.216241      21.940633            21.243149      12.857221
# std        24.413082      65.783983             9.650904      11.492508
# min       -41.300000    -175.200000           -29.800000       3.600000
# 25%         4.050300      -6.836100            15.600000       6.100000
# 50%        17.250000      23.236100            23.800000      10.800000
# 75%        40.400000      49.882200            28.000000      17.600000
# max        64.150000     179.220000            79.300000    2963.200000
#
#          wind_degree    pressure_mb     precip_mm       humidity  \
# count  140923.000000  140923.000000  140923.00000  140923.000000
# mean      168.800685    1014.053292       0.13317      66.731733
# std       103.725086      10.215805       0.55709      23.813318
# min         1.000000     947.000000       0.00000       2.000000
# 25%        80.000000    1010.000000       0.00000      51.000000
# 50%       161.000000    1013.000000       0.00000      72.000000
# 75%       256.000000    1018.000000       0.02000      86.000000
# max       360.000000    3006.000000      42.24000     100.000000
#
#                cloud  feels_like_celsius  ...       gust_kph  \
# count  140923.000000       140923.000000  ...  140923.000000
# mean       39.847009           22.096876  ...      18.192991
# std        34.085906           11.554897  ...      13.712501
# min         0.000000          -36.700000  ...       3.600000
# 25%         0.000000           15.700000  ...      10.200000
# 50%        29.000000           25.100000  ...      15.300000
# 75%        75.000000           29.900000  ...      24.100000
# max       100.000000           81.300000  ...    2970.400000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                140923.000000      140923.000000
# mean                    452.961460          57.731223
# std                     747.410497          30.513048
# min                   -9999.000000           0.000000
# 25%                     197.850000          38.000000
# 50%                     288.850000          55.000000
# 75%                     454.000000          73.000000
# max                   38879.398000         480.700000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                 140923.000000                140923.000000
# mean                      14.864649                    10.178871
# std                       23.431508                    35.009131
# min                        0.000000                 -9999.000000
# 25%                        1.750000                     1.110000
# 50%                        5.700000                     2.405000
# 75%                       17.205000                     8.140000
# max                      427.700000                   521.330000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count      140923.000000     140923.000000             140923.000000
# mean           23.924115         47.854728                  1.689582
# std            36.373748        147.491532                  0.934690
# min             0.168000      -1848.150000                  1.000000
# 25%             7.030000          9.850000                  1.000000
# 50%            14.050000         19.750000                  1.000000
# 75%            27.450000         41.050000                  2.000000
# max          1614.100000       6037.290000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count               140923.000000      140923.000000
# mean                     2.583056          50.079348
# std                      2.426315          35.024991
# min                      1.000000           0.000000
# 25%                      1.000000          15.000000
# 50%                      2.000000          50.000000
# 75%                      3.000000          85.000000
# max                     10.000000         100.000000
#
# [8 rows x 22 columns]

# %%
df = df.rename(columns = {
    'condition_text':'y'
})

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [country, location_name, latitude, longitude, timezone, last_updated, temperature_celsius, y, wind_kph, wind_degree, wind_direction, pressure_mb, precip_mm, humidity, cloud, feels_like_celsius, visibility_km, uv_index, gust_kph, air_quality_Carbon_Monoxide, air_quality_Ozone, air_quality_Nitrogen_dioxide, air_quality_Sulphur_dioxide, air_quality_PM2.5, air_quality_PM10, air_quality_us-epa-index, air_quality_gb-defra-index, sunrise, sunset, moonrise, moonset, moon_phase, moon_illumination]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# No NaN value

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [country, location_name, latitude, longitude, timezone, last_updated, temperature_celsius, y, wind_kph, wind_degree, wind_direction, pressure_mb, precip_mm, humidity, cloud, feels_like_celsius, visibility_km, uv_index, gust_kph, air_quality_Carbon_Monoxide, air_quality_Ozone, air_quality_Nitrogen_dioxide, air_quality_Sulphur_dioxide, air_quality_PM2.5, air_quality_PM10, air_quality_us-epa-index, air_quality_gb-defra-index, sunrise, sunset, moonrise, moonset, moon_phase, moon_illumination]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# No Null value

# %%
df["y"] = df["y"].str.strip().str.lower()

# %% [markdown]
# Normalizing y text

# %%
top_y = df["y"].value_counts().nlargest(15).index

filtered_df = df.copy()

# If NOT on the top y, is rest
filtered_df["y"] = filtered_df["y"].apply(
    lambda x: x if x in top_y else "rest"
)

df["y"].value_counts().nlargest(15)
# Out:
# y
# partly cloudy                          49342
# sunny                                  40554
# patchy rain nearby                     11788
# overcast                                7663
# clear                                   7545
# mist                                    5892
# light rain                              4403
# light rain shower                       3212
# fog                                     1749
# cloudy                                  1702
# moderate or heavy rain with thunder     1126
# moderate rain                           1063
# patchy light rain with thunder           874
# light drizzle                            705
# light snow                               525
# Name: count, dtype: int64

# %% [markdown]
# ### Weather Distribution Graph

# %%
weather_count = filtered_df["y"].value_counts()

fig, ax = plt.subplots(1, 1, figsize=(25,10))

sns.barplot(y=weather_count.values, hue=weather_count.index, ax=ax, palette="viridis")
ax.set_title("Distribution of Weathers")
ax.set_xlabel("Weather")
ax.tick_params(axis='x', labelrotation=90)
ax.set_ylabel("Number of records")
# Out:
# Text(0, 0.5, 'Number of records')

# %% [markdown]
# ### Country Distribuition Graph

# %%
countries_grouped = df.groupby("country").size()

countries_grouped.plot(kind="barh", figsize=(25,50))
# Out:
# <Axes: ylabel='country'>
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 28779 (\N{CJK UNIFIED IDEOGRAPH-706B}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 40481 (\N{CJK UNIFIED IDEOGRAPH-9E21}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 28779 (\N{CJK UNIFIED IDEOGRAPH-706B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 40481 (\N{CJK UNIFIED IDEOGRAPH-9E21}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Distribution of Temperature by Weather

# %%
fig, ax = plt.subplots(1,1, figsize=(20,20))

sns.violinplot(data=filtered_df, y="temperature_celsius", hue="y" , ax=ax, palette="viridis")
ax.set_title("Distribution of Temperature (°C)")
ax.set_xlabel("Weather")
ax.tick_params(axis='x', labelrotation=90)
ax.set_ylabel("Temperature (°C)")
# Out:
# Text(0, 0.5, 'Temperature (°C)')

# %% [markdown]
# ### Distribution of Precipitation by Weather

# %%
fig, ax = plt.subplots(1,1, figsize=(20,20))

sns.boxplot(data=filtered_df, y="y", x="precip_mm", ax=ax, palette="viridis")

ax.set_title("Distribution of Precipitation (mm)")
ax.set_ylabel("Weather")
ax.set_xscale("log")
ax.set_xlabel("Precipitation (mm)")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12632\608267091.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=filtered_df, y="y", x="precip_mm", ax=ax, palette="viridis")
# Text(0.5, 0, 'Precipitation (mm)')

# %% [markdown]
# ### Correlation of Humidity by Temperature

# %%
fig, ax = plt.subplots(1,1, figsize=(14,10))

sns.scatterplot(data=filtered_df, x="humidity", y="temperature_celsius")
ax.set_title("Correlation between Humidity and Temperature (°C)")
ax.set_ylabel("Temperature (°C)")
ax.set_xlabel("Humidity (%)")
# Out:
# Text(0.5, 0, 'Humidity (%)')

# %% [markdown]
# ### Correlation of Wind Speed (Kph) by Precipitation (mm)

# %%
fig, ax = plt.subplots(1,1, figsize=(14,10))

sns.scatterplot(data=filtered_df, y="wind_kph", x="precip_mm")
ax.set_title("Correlation between Wind Speed (Kph) and Precipitation (mm)")
ax.set_ylabel("Wind Speed (Kph)")
ax.set_yscale("log")
ax.set_xlabel("Precipitation (mm)")
ax.set_xscale("log")

# %% [markdown]
# ### Correlation between Air Quality and Precipitation

# %%
fig, ax = plt.subplots(1,1, figsize=(14,10))

sns.scatterplot(data=filtered_df, y="precip_mm", x="air_quality_PM2.5")
ax.set_title("Correlation between Precipitation (mm) and Air Quality (PM 2.5)")
ax.set_ylabel("Precipitation (mm)")
ax.set_yscale("log")
ax.set_xlabel("Air Quality (PM2.5)")
ax.set_xscale("log")

# %%
fig, ax = plt.subplots(1,1, figsize=(14,10))

sns.scatterplot(data=filtered_df, y="precip_mm", x="air_quality_Ozone")
ax.set_title("Correlation between Precipitation (mm) and Air Quality (Ground-level Ozone)")
ax.set_ylabel("Precipitation (mm)")
ax.set_yscale("log")
ax.set_xlabel("Air Quality (Ground-level Ozone)")
ax.set_xscale("log")

# %%
fig, ax = plt.subplots(1,1, figsize=(14,10))

sns.scatterplot(data=filtered_df, y="precip_mm", x="air_quality_Carbon_Monoxide")
ax.set_title("Correlation between Precipitation (mm) and Air Quality (Carbon monoxide CO)")
ax.set_ylabel("Precipitation (mm)")
ax.set_yscale("log")
ax.set_xlabel("Air Quality (Carbon monoxide CO)")
ax.set_xscale("log")

# %%
fig, ax = plt.subplots(1,1, figsize=(14,10))

sns.scatterplot(data=filtered_df, y="precip_mm", x="air_quality_Sulphur_dioxide")
ax.set_title("Correlation between Precipitation (mm) and Air Quality (Sulfur dioxide SO2)")
ax.set_ylabel("Precipitation (mm)")
ax.set_yscale("log")
ax.set_xlabel("Air Quality (Sulfur dioxide SO2)")
ax.set_xscale("log")

# %% [markdown]
# ## Normalizing Data

# %% [markdown]
# Location and Country can be removed for some reasons, the first being the impracticality of encoding them, and all the geological information about it can be gathered from the latitude and longitude.

# %%
filtered_df = filtered_df.drop(columns=["location_name", "country", "timezone", 'wind_direction'])

# %%
onehot_encoding = ["moon_phase", "wind_direction", "y"]

# %%
time_features = ["sunrise", "sunset", "moonrise", "moonset"]

# %%
def cyclic_encode(series, period):
    radians = 2 * np.pi * series / period

    sin = np.sin(radians)
    cos = np.cos(radians)

    return sin, cos

# %%
def transform_data_set(dataframe, property_name, period):
    
    dataframe[f"{property_name}_sin"], dataframe[f"{property_name}_cos"] = cyclic_encode(
    dataframe[property_name],
    period
    )
    
    dataframe = dataframe.drop(columns=[property_name])
    
    return dataframe

# %%
filtered_df["last_updated"] = pd.to_datetime(filtered_df["last_updated"])

# %%
filtered_df["year"] = filtered_df["last_updated"].dt.year

filtered_df["year"].value_counts().index
# Out:
# Index([2025, 2024, 2026], dtype='int32', name='year')

# %%
filtered_df["month"] = filtered_df["last_updated"].dt.month

filtered_df["month"].value_counts().index
# Out:
# Index([12, 8, 10, 3, 1, 9, 4, 11, 5, 6, 7, 2], dtype='int32', name='month')

# %%
filtered_df["hour"] = filtered_df["last_updated"].dt.hour

# %%
filtered_df = filtered_df.drop(columns=["last_updated"])

# %%
for time in time_features:
    parsed_time = pd.to_datetime(
        filtered_df[time],
        format="%I:%M %p",
        errors="coerce"
    )

    filtered_df[time] = (
        parsed_time.dt.hour +
        parsed_time.dt.minute / 60
    )

    filtered_df = transform_data_set(filtered_df, time, 24)

# %%
filtered_df = transform_data_set(filtered_df, "wind_degree", 24)

# %%
filtered_df = transform_data_set(filtered_df, "hour", 24)

# %%
filtered_df = transform_data_set(filtered_df, "month", 12)

# %%
filtered_df.columns
# Out:
# Index(['latitude', 'longitude', 'temperature_celsius', 'y', 'wind_kph',
#        'pressure_mb', 'precip_mm', 'humidity', 'cloud', 'feels_like_celsius',
#        'visibility_km', 'uv_index', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'moon_phase',
#        'moon_illumination', 'year', 'sunrise_sin', 'sunrise_cos', 'sunset_sin',
#        'sunset_cos', 'moonrise_sin', 'moonrise_cos', 'moonset_sin',
#        'moonset_cos', 'wind_degree_sin', 'wind_degree_cos', 'hour_sin',
#        'hour_cos', 'month_sin', 'month_cos'],
#       dtype='object')

# %%
for col in filtered_df.columns:
    print(type(filtered_df[col].iloc[0]))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'str'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'numpy.int32'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %% [markdown]
# ## Outliers

# %% [raw]
# iso_forest = IsolationForest(contamination=0.2)
# iso_forest.fit(filtered_df)
# predictions = iso_forest.predict(filtered_df)
#
# predictions
